# %%
import feedparser
import requests
import time
import csv
import urllib, urllib.request
from datetime import datetime
import pytz

# %%
BASE_URL = "http://export.arxiv.org/api/query?"

# %%
def search_arxiv(keywords, start, max_results=10):
    terms = keywords.split()

    query = " AND ".join(
        f"(ti:{t} OR abs:{t})" for t in terms
    )

    params = {
        "search_query": query,
        "start": start,
        "max_results": max_results,
        "sortBy": "submittedDate",
        "sortOrder": "descending"
    }

    response = requests.get(BASE_URL, params=params)
    print(response.url)  # 🔍 depuración REAL

    feed = feedparser.parse(response.text)

    papers = []

    for entry in feed.entries:
        paper = {
            "arxiv_id": entry.id.split("/abs/")[-1],
            "title": entry.title.strip().replace("\n", " "),
            "abstract": entry.summary.strip().replace("\n", " "),
            "published": entry.published,
            "authors": [author.name for author in entry.authors],
            "categories": [tag["term"] for tag in entry.tags],
            "doi": entry.get("arxiv_doi", None),
            "pdf_url": next(
                (link.href for link in entry.links if link.type == "application/pdf"),
                None
            )
        }

        papers.append(paper)

    return papers

# %%
#termino_busqueda = "active aging elderly"
busquedas = ["active aging elderly", 
             "recommender systems human learning",  #necesario añadir human
             "ontology movement", 
             "human movement language models",  #necesario añadir human
             "tai chi", #produce muy pocos resultados en arXiv
             "pathology ontology",
             ]
starting_point = 0
n_results = 5
years_back = 5
current_year = time.localtime().tm_year
ending_year = current_year - years_back

# %%
def save_papers_to_csv(papers, filename):
    if not papers:
        return

    fieldnames = papers[0].keys()

    with open(filename, mode="w", newline="", encoding="utf-8") as f:
        writer = csv.DictWriter(f, fieldnames=fieldnames)
        writer.writeheader()

        for paper in papers:
            writer.writerow({
                k: ", ".join(v) if isinstance(v, list) else v
                for k, v in paper.items()
            })

# %%
for i in busquedas:
    termino_busqueda = i
    paper_year = current_year
    papers_list = []
    print("Buscando papers para el término:", termino_busqueda, paper_year)
    while paper_year > ending_year:
        papers = search_arxiv(termino_busqueda, start=starting_point, max_results=starting_point+n_results)
        if len(papers) == 0:
            break
        last_paper = papers[-1]
        date_str = last_paper["published"]
        dt_utc = datetime.strptime(date_str, "%Y-%m-%dT%H:%M:%SZ")
        dt_utc = dt_utc.replace(tzinfo=pytz.UTC)
        local_tz = pytz.timezone("Europe/Madrid")  # cambia si hace falta
        dt_local = dt_utc.astimezone(local_tz)
        paper_year = dt_local.year
        papers_list.extend(papers)
        starting_point += n_results
        print("Año del último paper obtenido:", paper_year, "Total de papers acumulados:", len(papers_list))
        if len(papers_list) >= 500:
            print("Límite de 500 papers alcanzado, deteniendo la búsqueda.")
            break
    save_papers_to_csv(papers_list, "arxiv_{}.csv".format(termino_busqueda.replace(" ", "_")))
# Out:
# Buscando papers para el término: active aging elderly
# https://export.arxiv.org/api/query?search_query=%28ti%3Aactive+OR+abs%3Aactive%29+AND+%28ti%3Aaging+OR+abs%3Aaging%29+AND+%28ti%3Aelderly+OR+abs%3Aelderly%29&start=0&max_results=5&sortBy=submittedDate&sortOrder=descending
# Año del último paper obtenido: 2025 Total de papers acumulados: 5
# https://export.arxiv.org/api/query?search_query=%28ti%3Aactive+OR+abs%3Aactive%29+AND+%28ti%3Aaging+OR+abs%3Aaging%29+AND+%28ti%3Aelderly+OR+abs%3Aelderly%29&start=5&max_results=10&sortBy=submittedDate&sortOrder=descending
# Año del último paper obtenido: 2024 Total de papers acumulados: 15
# https://export.arxiv.org/api/query?search_query=%28ti%3Aactive+OR+abs%3Aactive%29+AND+%28ti%3Aaging+OR+abs%3Aaging%29+AND+%28ti%3Aelderly+OR+abs%3Aelderly%29&start=10&max_results=15&sortBy=submittedDate&sortOrder=descending
# Año del último paper obtenido: 2022 Total de papers acumulados: 30
# https://export.arxiv.org/api/query?search_query=%28ti%3Aactive+OR+abs%3Aactive%29+AND+%28ti%3Aaging+OR+abs%3Aaging%29+AND+%28ti%3Aelderly+OR+abs%3Aelderly%29&start=15&max_results=20&sortBy=submittedDate&sortOrder=descending
# Año del último paper obtenido: 2021 Total de papers acumulados: 50
# Buscando papers para el término: recommender systems human learning
# https://export.arxiv.org/api/query?search_query=%28ti%3Arecommender+OR+abs%3Arecommender%29+AND+%28ti%3Asystems+OR+abs%3Asystems%29+AND+%28ti%3Ahuman+OR+abs%3Ahuman%29+AND+%28ti%3Alearning+OR+abs%3Alearning%29&start=20&max_results=25&sortBy=submittedDate&sortOrder=descending
# Año del último paper obtenido: 2025 Total de papers acumulados: 25
# https://export.arxiv.org/api/query?search_query=%28ti%3Arecommender+OR+abs%3Arecommender%29+AND+%28ti%3Asystems+OR+abs%3Asystems%29+AND+%28ti%3Ahuman+OR+abs%3Ahuman%29+AND+%28ti%3Alearning+OR+abs%3Alearning%29&start=25&max_results=30&sortBy=submittedDate&sortOrder=descending
# Año del último paper obtenido: 2025 Total de papers acumulados: 55
# https://export.arxiv.org/api/query?search_query=%28ti%3Arecommender+OR+abs%3Arecommender%29+AND+%28ti%3Asystems+OR+abs%3Asystems%29+AND+%28ti%3Ahuman+OR+abs%3Ahuman%29+AND+%28ti%3Alearning+OR+abs%3Alearning%29&start=30&max_results=35&sortBy=submittedDate&sortOrder=descending
# Año del último paper obtenido: 2025 Total de papers acumulados: 90
# https://export.arxiv.org/api/query?search_query=%28ti%3Arecommender+OR+abs%3Arecommender%29+AND+%28ti%3Asystems+OR+abs%3Asystems%29+AND+%28ti%3Ahuman+OR+abs%3Ahuman%29+AND+%28ti%3Alearning+OR+abs%3Alearning%29&start=35&max_results=40&sortBy=submittedDate&sortOrder=descending
# Año del último paper obtenido: 2025 Total de papers acumulados: 130
# https://export.arxiv.org/api/query?search_query=%28ti%3Arecommender+OR+abs%3Arecommender%29+AND+%28ti%3Asystems+OR+abs%3Asystems%29+AND+%28ti%3Ahuman+OR+abs%3Ahuman%29+AND+%28ti%3Alearning+OR+abs%3Alearning%29&start=40&max_results=45&sortBy=submittedDate&sortOrder=descending
# Año del último paper obtenido: 2025 Total de papers acumulados: 175
# https://export.arxiv.org/api/query?search_query=%28ti%3Arecommender+OR+abs%3Arecommender%29+AND+%28ti%3Asystems+OR+abs%3Asystems%29+AND+%28ti%3Ahuman+OR+abs%3Ahuman%29+AND+%28ti%3Alearning+OR+abs%3Alearning%29&start=45&max_results=50&sortBy=submittedDate&sortOrder=descending
# Año del último paper obtenido: 2025 Total de papers acumulados: 225
# https://export.arxiv.org/api/query?search_query=%28ti%3Arecommender+OR+abs%3Arecommender%29+AND+%28ti%3Asystems+OR+abs%3Asystems%29+AND+%28ti%3Ahuman+OR+abs%3Ahuman%29+AND+%28ti%3Alearning+OR+abs%3Alearning%29&start=50&max_results=55&sortBy=submittedDate&sortOrder=descending
# Año del último paper obtenido: 2024 Total de papers acumulados: 280
# https://export.arxiv.org/api/query?search_query=%28ti%3Arecommender+OR+abs%3Arecommender%29+AND+%28ti%3Asystems+OR+abs%3Asystems%29+AND+%28ti%3Ahuman+OR+abs%3Ahuman%29+AND+%28ti%3Alearning+OR+abs%3Alearning%29&start=55&max_results=60&sortBy=submittedDate&sortOrder=descending
# Año del último paper obtenido: 2024 Total de papers acumulados: 340
# https://export.arxiv.org/api/query?search_query=%28ti%3Arecommender+OR+abs%3Arecommender%29+AND+%28ti%3Asystems+OR+abs%3Asystems%29+AND+%28ti%3Ahuman+OR+abs%3Ahuman%29+AND+%28ti%3Alearning+OR+abs%3Alearning%29&start=60&max_results=65&sortBy=submittedDate&sortOrder=descending
# Año del último paper obtenido: 2024 Total de papers acumulados: 405
# https://export.arxiv.org/api/query?search_query=%28ti%3Arecommender+OR+abs%3Arecommender%29+AND+%28ti%3Asystems+OR+abs%3Asystems%29+AND+%28ti%3Ahuman+OR+abs%3Ahuman%29+AND+%28ti%3Alearning+OR+abs%3Alearning%29&start=65&max_results=70&sortBy=submittedDate&sortOrder=descending
# Año del último paper obtenido: 2024 Total de papers acumulados: 475
# https://export.arxiv.org/api/query?search_query=%28ti%3Arecommender+OR+abs%3Arecommender%29+AND+%28ti%3Asystems+OR+abs%3Asystems%29+AND+%28ti%3Ahuman+OR+abs%3Ahuman%29+AND+%28ti%3Alearning+OR+abs%3Alearning%29&start=70&max_results=75&sortBy=submittedDate&sortOrder=descending
# Año del último paper obtenido: 2024 Total de papers acumulados: 550
# Límite de 500 papers alcanzado, deteniendo la búsqueda.
# Buscando papers para el término: ontology movement
# https://export.arxiv.org/api/query?search_query=%28ti%3Aontology+OR+abs%3Aontology%29+AND+%28ti%3Amovement+OR+abs%3Amovement%29&start=75&max_results=80&sortBy=submittedDate&sortOrder=descending
# Buscando papers para el término: human movement language models
# https://export.arxiv.org/api/query?search_query=%28ti%3Ahuman+OR+abs%3Ahuman%29+AND+%28ti%3Amovement+OR+abs%3Amovement%29+AND+%28ti%3Alanguage+OR+abs%3Alanguage%29+AND+%28ti%3Amodels+OR+abs%3Amodels%29&start=75&max_results=80&sortBy=submittedDate&sortOrder=descending
# Año del último paper obtenido: 2024 Total de papers acumulados: 80
# https://export.arxiv.org/api/query?search_query=%28ti%3Ahuman+OR+abs%3Ahuman%29+AND+%28ti%3Amovement+OR+abs%3Amovement%29+AND+%28ti%3Alanguage+OR+abs%3Alanguage%29+AND+%28ti%3Amodels+OR+abs%3Amodels%29&start=80&max_results=85&sortBy=submittedDate&sortOrder=descending
# Año del último paper obtenido: 2024 Total de papers acumulados: 165
# https://export.arxiv.org/api/query?search_query=%28ti%3Ahuman+OR+abs%3Ahuman%29+AND+%28ti%3Amovement+OR+abs%3Amovement%29+AND+%28ti%3Alanguage+OR+abs%3Alanguage%29+AND+%28ti%3Amodels+OR+abs%3Amodels%29&start=85&max_results=90&sortBy=submittedDate&sortOrder=descending
# Año del último paper obtenido: 2024 Total de papers acumulados: 255
# https://export.arxiv.org/api/query?search_query=%28ti%3Ahuman+OR+abs%3Ahuman%29+AND+%28ti%3Amovement+OR+abs%3Amovement%29+AND+%28ti%3Alanguage+OR+abs%3Alanguage%29+AND+%28ti%3Amodels+OR+abs%3Amodels%29&start=90&max_results=95&sortBy=submittedDate&sortOrder=descending
# Año del último paper obtenido: 2023 Total de papers acumulados: 350
# https://export.arxiv.org/api/query?search_query=%28ti%3Ahuman+OR+abs%3Ahuman%29+AND+%28ti%3Amovement+OR+abs%3Amovement%29+AND+%28ti%3Alanguage+OR+abs%3Alanguage%29+AND+%28ti%3Amodels+OR+abs%3Amodels%29&start=95&max_results=100&sortBy=submittedDate&sortOrder=descending
# Año del último paper obtenido: 2023 Total de papers acumulados: 450
# https://export.arxiv.org/api/query?search_query=%28ti%3Ahuman+OR+abs%3Ahuman%29+AND+%28ti%3Amovement+OR+abs%3Amovement%29+AND+%28ti%3Alanguage+OR+abs%3Alanguage%29+AND+%28ti%3Amodels+OR+abs%3Amodels%29&start=100&max_results=105&sortBy=submittedDate&sortOrder=descending
# Año del último paper obtenido: 2023 Total de papers acumulados: 555
# Límite de 500 papers alcanzado, deteniendo la búsqueda.
# Buscando papers para el término: tai chi
# https://export.arxiv.org/api/query?search_query=%28ti%3Atai+OR+abs%3Atai%29+AND+%28ti%3Achi+OR+abs%3Achi%29&start=105&max_results=110&sortBy=submittedDate&sortOrder=descending
# Buscando papers para el término: pathology ontology
# https://export.arxiv.org/api/query?search_query=%28ti%3Apathology+OR+abs%3Apathology%29+AND+%28ti%3Aontology+OR+abs%3Aontology%29&start=105&max_results=110&sortBy=submittedDate&sortOrder=descending

# %%
for p in papers:
    print(p["title"])
    print(p["doi"])
    print(p["published"])
    date_str = p["published"]
    dt_utc = datetime.strptime(date_str, "%Y-%m-%dT%H:%M:%SZ")
    dt_utc = dt_utc.replace(tzinfo=pytz.UTC)
    dt_local = dt_utc.astimezone(dt_utc.tzinfo)
    print(dt_local.year)
    print(p["categories"])
    print("-" * 40)
